# %%
import pandas as pd
ipl_matches_df = pd.read_csv('C:\\Users\\vaishnavi\\Downloads\\IPL Matches 2008-2020.csv')

# %%
ipl_matches_df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl_matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
ipl_matches_df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
ipl_matches_df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
for col in ipl_matches_df:
    print(ipl_matches_df[col].unique())
# Out:
# [ 335982  335983  335984  335985  335986  335987  335988  335989  335990
#   335991  335992  335993  335994  335995  335996  335997  335998  335999
#   336000  336001  336002  336003  336004  336005  336006  336007  336008
#   336009  336010  336011  336012  336013  336014  336015  336016  336017
#   336018  336019  336020  336021  336022  336023  336024  336025  336026
#   336027  336028  336029  336031  336032  336033  336034  336035  336036
#   336037  336038  336039  336040  392181  392182  392183  392184  392185
#   392186  392188  392189  392190  392191  392192  392194  392195  392196
#   392197  392198  392199  392200  392201  392202  392203  392204  392205
#   392206  392207  392208  392209  392210  392211  392212  392213  392214
#   392215  392216  392217  392218  392219  392220  392221  392222  392223
#   392224  392225  392226  392227  392228  392229  392230  392231  392232
#   392233  392234  392235  392236  392237  392238  392239  419106  419107
# ...

# %%
#the first index that doesn't contain a NaN value 
ipl_matches_df.method.first_valid_index()
# Out:
# 40

# %%
#Confirming the first valid index
ipl_matches_df.loc[39:45]
# Out:
#         id       city        date   player_of_match  \
# 39  336021     Mumbai  2008-05-16        SM Pollock
# 40  336022      Delhi  2008-05-17  DPMD Jayawardene
# 41  336023     Jaipur  2008-05-17          GC Smith
# 42  336024  Hyderabad  2008-05-18          DJ Bravo
# 43  336025    Kolkata  2008-05-18           M Ntini
# 44  336026  Bangalore  2008-05-19        SP Goswami
# 45  336027    Kolkata  2008-05-20         YK Pathan
#
#                                         venue  neutral_venue  \
# 39                           Wankhede Stadium              0
# 40                           Feroz Shah Kotla              0
# 41                     Sawai Mansingh Stadium              0
# 42  Rajiv Gandhi International Stadium, Uppal              0
# 43                               Eden Gardens              0
# 44                      M Chinnaswamy Stadium              0
# 45                               Eden Gardens              0
#
# ...

# %%
ipl_matches_df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
ipl_matches_df = ipl_matches_df.drop(columns=['method'], axis=1)

# %%
ipl_matches_df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.color_palette("Paired")
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12, 8)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
#team with the most wins in each season.  ##############yearperteam cant find

teams_per_season = ipl_matches_df.groupby('date')['winner'].value_counts()
teams_per_season
# Out:
# date        winner
# 2008-04-18  Kolkata Knight Riders          1
# 2008-04-19  Chennai Super Kings            1
#             Delhi Daredevils               1
# 2008-04-20  Kolkata Knight Riders          1
#             Royal Challengers Bangalore    1
#                                           ..
# 2020-11-03  Sunrisers Hyderabad            1
# 2020-11-05  Mumbai Indians                 1
# 2020-11-06  Sunrisers Hyderabad            1
# 2020-11-08  Delhi Capitals                 1
# 2020-11-10  Mumbai Indians                 1
# Name: winner, Length: 812, dtype: int64

# %%
"""
for i, v in win_per_season.iteritems():
    print(i, v)
    
for items in win_per_season.iteritems():
    print(items)    
"""
year = 2008
win_per_season_df = pd.DataFrame(columns=['year', 'team', 'wins'])
for items in teams_per_season.iteritems():    
    if items[0][0]==year:
        print(items)
        win_series = pd.DataFrame({
            'year': [items[0][0]],
            'team': [items[0][1]],
            'wins': [items[1]]
        })
        win_per_season_df = win_per_season_df.append(win_series)
        year += 1

# %%
win_per_season_df   ############
# Out:
# Empty DataFrame
# Columns: [year, team, wins]
# Index: []

# %%
sns.barplot('wins', 'team', hue='year', data=win_per_season_df, palette='Paired');  #####################3

# %%
#The venue that hosted the maximum number of matches

venue_ser = ipl_matches_df['venue'].value_counts()

# %%
venue_df = pd.DataFrame(columns=['venue', 'matches'])
for items in venue_ser.iteritems():
    temp_df = pd.DataFrame({
        'venue':[items[0]],
        'matches':[items[1]]
    })
    venue_df = venue_df.append(temp_df, ignore_index=True)

# %%
plt.title("IPL Venues")
sns.barplot(x='matches', y='venue', data=venue_df);

# %%
venue_df
# Out:
#                                                 venue matches
# 0                                        Eden Gardens      77
# 1                                    Feroz Shah Kotla      74
# 2                                    Wankhede Stadium      73
# 3                               M Chinnaswamy Stadium      65
# 4           Rajiv Gandhi International Stadium, Uppal      64
# 5                     MA Chidambaram Stadium, Chepauk      57
# 6                              Sawai Mansingh Stadium      47
# 7          Punjab Cricket Association Stadium, Mohali      35
# 8                 Dubai International Cricket Stadium      33
# 9                                Sheikh Zayed Stadium      29
# 10  Punjab Cricket Association IS Bindra Stadium, ...      21
# 11            Maharashtra Cricket Association Stadium      21
# 12                            Sharjah Cricket Stadium      18
# 13                         Dr DY Patil Sports Academy      17
# ...

# %%
#The most successful IPL team

team_wins_ser = ipl_matches_df['winner'].value_counts()

team_wins_df = pd.DataFrame(columns=["team", "wins"])
for items in team_wins_ser.iteritems():
    temp_df1 = pd.DataFrame({
        'team':[items[0]],
        'wins':[items[1]]
    })
    team_wins_df = team_wins_df.append(temp_df1, ignore_index=True)

# %%
team_wins_df
# Out:
#                            team wins
# 0                Mumbai Indians  120
# 1           Chennai Super Kings  106
# 2         Kolkata Knight Riders   99
# 3   Royal Challengers Bangalore   91
# 4               Kings XI Punjab   88
# 5              Rajasthan Royals   81
# 6              Delhi Daredevils   67
# 7           Sunrisers Hyderabad   66
# 8               Deccan Chargers   29
# 9                Delhi Capitals   19
# 10                Gujarat Lions   13
# 11                Pune Warriors   12
# 12       Rising Pune Supergiant   10
# 13         Kochi Tuskers Kerala    6
# 14      Rising Pune Supergiants    5

# %%
plt.title("Total Victories of IPL Teams")
sns.barplot(x='wins', y='team', data=team_wins_df, palette='Paired');

# %%
#Most Valuable Player

mvp_ser = ipl_matches_df['player_of_match'].value_counts()

mvp_ten_df = pd.DataFrame(columns=["player", "wins"])
count = 0
for items in mvp_ser.iteritems():
    if count>9:
        break
    else:
        temp_df2 = pd.DataFrame({
            'player':[items[0]],
            'wins':[items[1]]
        })
        mvp_ten_df = mvp_ten_df.append(temp_df2, ignore_index=True)
        count += 1

# %%
mvp_ten_df
# Out:
#            player wins
# 0  AB de Villiers   23
# 1        CH Gayle   22
# 2       RG Sharma   18
# 3        MS Dhoni   17
# 4       DA Warner   17
# 5       YK Pathan   16
# 6       SR Watson   16
# 7        SK Raina   14
# 8         V Kohli   13
# 9       G Gambhir   13

# %%
plt.title("Top Ten IPL Players")
sns.barplot(x='wins', y='player', data=mvp_ten_df, palette='Paired');

# %%
#The team that won the most number of toss

toss_ser = ipl_matches_df['toss_winner'].value_counts()

toss_df = pd.DataFrame(columns=["team", "wins"])

for items in toss_ser.iteritems():
    temp_df3 = pd.DataFrame({
        'team':[items[0]],
        'wins':[items[1]]
    })
    toss_df = toss_df.append(temp_df3, ignore_index=True)

# %%
toss_df
# Out:
#                            team wins
# 0                Mumbai Indians  106
# 1         Kolkata Knight Riders   98
# 2           Chennai Super Kings   97
# 3   Royal Challengers Bangalore   87
# 4              Rajasthan Royals   87
# 5               Kings XI Punjab   85
# 6              Delhi Daredevils   80
# 7           Sunrisers Hyderabad   57
# 8               Deccan Chargers   43
# 9                Delhi Capitals   20
# 10                Pune Warriors   20
# 11                Gujarat Lions   15
# 12         Kochi Tuskers Kerala    8
# 13      Rising Pune Supergiants    7
# 14       Rising Pune Supergiant    6

# %%
plt.title("How IPL Teams fared in toss?")
sns.barplot(x='wins', y='team', data=toss_df, palette='Paired');

# %%
####Observations:
#The venue that hosted the maximum number of matches ------> Eden Gardens : 77 matches
#The most successful IPL team --------> Mumabai Indians : 120 wins
#Most Valuable Player ----------> AB de Villiers : 23 wins
#team that won the most number of toss ----------> Mumbai Indians : 106 wins

# %%
#Does the presence of the most valuable players in a team ensures the IPL trophy?

mvp_ten_df

#Top two Players (Chris Gayle and AB de Villers) have never won an IPL So 6 players of top ten hav won IPL. It examines the importance of the most valuable player in team.
# Out:
#            player wins
# 0  AB de Villiers   23
# 1        CH Gayle   22
# 2       RG Sharma   18
# 3        MS Dhoni   17
# 4       DA Warner   17
# 5       YK Pathan   16
# 6       SR Watson   16
# 7        SK Raina   14
# 8         V Kohli   13
# 9       G Gambhir   13

# %%
#Which city has hosted the maximum number of IPL matches

ipl_matches_df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Centurion          12
# Sharjah            12
# Rajkot             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Cape Town           7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
city_ser = ipl_matches_df['city'].value_counts()

city_df = pd.DataFrame(columns=['city', 'matches'])
for items in city_ser.iteritems():
    temp_df6 = pd.DataFrame({
        'city':[items[0]],
        'matches':[items[1]]
    })
    city_df = city_df.append(temp_df6, ignore_index=True)

# %%
plt.title("Cities that hosted IPL matches")
sns.barplot(x='matches', y='city', data=city_df);

# %%
# So the Mumbai has hosted maximum number of matches
